# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
import pandas as pd

# %% [markdown]
# [Dataset Soruce](https://www.kaggle.com/datasets/rajkumarpandey02/gdp-in-usd-per-capita-income-by-country)

# %% [markdown]
# CONTENT
# <p>The figures presented here do not take into account differences in the cost of living in different countries, and the results vary greatly from one year to another based on fluctuations in the exchange rates of the country's currency. Such fluctuations change a country's ranking from one year to the next, even though they often make little or no difference to the standard of living of its population.
#
# GDP per capita is often considered an indicator of a country's standard of living; however, this is inaccurate because GDP per capita is not a measure of personal income.
#
# Comparisons of national income are also frequently made on the basis of purchasing power parity (PPP), to adjust for differences in the cost of living in different countries. (See List of countries by GDP (PPP) per capita.) PPP largely removes the exchange rate problem but not others; it does not reflect the value of economic output in international trade, and it also requires more estimation than GDP per capita. On the whole, PPP per capita figures are more narrowly spread than nominal GDP per capita figures.</p>

# %% [markdown]
# Here are some resources to learn about GDP:
# #### [World Bank](https://data.worldbank.org/indicator/ny.gdp.pcap.cd?most_recent_value_desc=false)
# #### [Our World in Data](https://ourworldindata.org/grapher/gdp-per-capita-worldbank)
# #### [IMF](https://www.imf.org/external/datamapper/NGDPD@WEO/OEMDC/ADVEC/WEOWORLD)
# #### [UN Data](https://data.un.org/Data.aspx?d=SNAAMA&f=grID%3A101%3BcurrID%3AUSD%3BpcFlag%3A1)

# %%
#Read and save the ‘GDP (nominal) per Capita’ data to a data frame called “df” in Jupyter notebook

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv("/content/drive/MyDrive/GDP(nominal)perCapita.csv")
df
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Country/Territory UN_Region  \
# 0               0             0           1            Monaco    Europe
# 1               1             1           2     Liechtenstein    Europe
# 2               2             2           3        Luxembourg    Europe
# 3               3             3           4           Ireland    Europe
# 4               4             4           5           Bermuda  Americas
# ..            ...           ...         ...               ...       ...
# 218           218           218         219            Malawi    Africa
# 219           219           219         220       South Sudan    Africa
# 220           220           220         221      Sierra Leone    Africa
# 221           221           221         222       Afghanistan      Asia
# 222           222           222         223           Burundi    Africa
#
#      IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0.2        223 non-null    int64
#  1   Unnamed: 0.1        223 non-null    int64
#  2   Unnamed: 0          223 non-null    int64
#  3   Country/Territory   223 non-null    object
#  4   UN_Region           223 non-null    object
#  5   IMF_Estimate        223 non-null    int64
#  6   IMF_Year            223 non-null    int64
#  7   WorldBank_Estimate  223 non-null    int64
#  8   WorldBank_Year      223 non-null    int64
#  9   UN_Estimate         223 non-null    int64
#  10  UN_Year             223 non-null    object
# dtypes: int64(8), object(3)
# memory usage: 19.3+ KB

# %%
pd.read_csv("/content/drive/MyDrive/GDP(nominal)perCapita.csv")
df.to_csv("/content/drive/MyDrive/GDP(nominal)perCapita.csv")

# %%
# Print the first 10 rows
df.head(10)
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Country/Territory UN_Region  \
# 0             0             0           1            Monaco    Europe
# 1             1             1           2     Liechtenstein    Europe
# 2             2             2           3        Luxembourg    Europe
# 3             3             3           4           Ireland    Europe
# 4             4             4           5           Bermuda  Americas
# 5             5             5           6            Norway    Europe
# 6             6             6           7       Switzerland    Europe
# 7             7             7           8         Singapore      Asia
# 8             8             8           9       Isle of Man    Europe
# 9             9             9          10    Cayman Islands  Americas
#
#    IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate  \
# 0             0         0              234316            2021       234317
# ...

# %%
# Print the first 10 rows with columns Country/Territory & UN_Region

df.loc[:9:, 'Country/Territory':'UN_Region']
# Out:
#   Country/Territory UN_Region
# 0            Monaco    Europe
# 1     Liechtenstein    Europe
# 2        Luxembourg    Europe
# 3           Ireland    Europe
# 4           Bermuda  Americas
# 5            Norway    Europe
# 6       Switzerland    Europe
# 7         Singapore      Asia
# 8       Isle of Man    Europe
# 9    Cayman Islands  Americas

# %%
print(df.loc[:9])
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Country/Territory UN_Region  \
# 0             0             0           1            Monaco    Europe
# 1             1             1           2     Liechtenstein    Europe
# 2             2             2           3        Luxembourg    Europe
# 3             3             3           4           Ireland    Europe
# 4             4             4           5           Bermuda  Americas
# 5             5             5           6            Norway    Europe
# 6             6             6           7       Switzerland    Europe
# 7             7             7           8         Singapore      Asia
# 8             8             8           9       Isle of Man    Europe
# 9             9             9          10    Cayman Islands  Americas
#
#    IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate  \
# 0             0         0              234316            2021       234317
# ...

# %%
# Print the last 5 rows

df.tail(5)
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 Country/Territory UN_Region  \
# 218           218           218         219            Malawi    Africa
# 219           219           219         220       South Sudan    Africa
# 220           220           220         221      Sierra Leone    Africa
# 221           221           221         222       Afghanistan      Asia
# 222           222           222         223           Burundi    Africa
#
#      IMF_Estimate  IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate  \
# 218           496      2023                 635            2021          613
# 219           467      2023                1072            2015          400
# 220           415      2023                 480            2021          505
# 221           611      2020                 369            2021          373
# 222           249      2023                 222            2021          311
#
#     UN_Year
# 218    2021
# 219    2021
# 220    2021
# 221    2021
# ...

# %%
# Print ‘Country/Territory’ and ‘UN_Region’ columns

print(df[['Country/Territory','UN_Region']])
# Out:
#     Country/Territory UN_Region
# 0              Monaco    Europe
# 1       Liechtenstein    Europe
# 2          Luxembourg    Europe
# 3             Ireland    Europe
# 4             Bermuda  Americas
# ..                ...       ...
# 218            Malawi    Africa
# 219       South Sudan    Africa
# 220      Sierra Leone    Africa
# 221       Afghanistan      Asia
# 222           Burundi    Africa
#
# [223 rows x 2 columns]

# %%
# Print ‘Country/Territory’ and ‘UN_Region’ columns

df.loc[:,'Country/Territory':'UN_Region']
# Out:
#     Country/Territory UN_Region
# 0              Monaco    Europe
# 1       Liechtenstein    Europe
# 2          Luxembourg    Europe
# 3             Ireland    Europe
# 4             Bermuda  Americas
# ..                ...       ...
# 218            Malawi    Africa
# 219       South Sudan    Africa
# 220      Sierra Leone    Africa
# 221       Afghanistan      Asia
# 222           Burundi    Africa
#
# [223 rows x 2 columns]

# %%
df.groupby("UN_Region").count()
# Out:
#            Unnamed: 0.1  Unnamed: 0  Country/Territory  IMF_Estimate  \
# UN_Region
# Africa               55          55                 55            55
# Americas             48          48                 48            48
# Asia                 51          51                 51            51
# Europe               48          48                 48            48
# Oceania              20          20                 20            20
# World                 1           1                  1             1
#
#            IMF_Year  WorldBank_Estimate  WorldBank_Year  UN_Estimate  UN_Year
# UN_Region
# Africa           55                  55              55           55       55
# Americas         48                  48              48           48       48
# Asia             51                  51              51           51       51
# Europe           48                  48              48           48       48
# ...

# %%
df.groupby("UN_Region").get_group("Europe")
# Out:
#      Unnamed: 0.1  Unnamed: 0       Country/Territory UN_Region  IMF_Estimate  \
# 0               0           1                  Monaco    Europe             0
# 1               1           2           Liechtenstein    Europe             0
# 2               2           3              Luxembourg    Europe        132372
# 3               3           4                 Ireland    Europe        114581
# 5               5           6                  Norway    Europe        101103
# 6               6           7             Switzerland    Europe         98767
# 8               8           9             Isle of Man    Europe             0
# 12             12          13                 Iceland    Europe         75180
# 13             13          14         Channel Islands    Europe             0
# 14             14          15           Faroe Islands    Europe             0
# 15             15          16                 Denmark    Europe         68827
# ...

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Use this section to explore and inspect dataset.

# %%
df.groupby("UN_Region")['Country/Territory'].count()
# Out:
# UN_Region
# Africa      55
# Americas    48
# Asia        51
# Europe      48
# Oceania     20
# World        1
# Name: Country/Territory, dtype: int64

# %%
df.groupby("UN_Region").get_group("Asia").sort_values(by="Country/Territory")
# Out:
#      Unnamed: 0.1  Unnamed: 0     Country/Territory UN_Region  IMF_Estimate  \
# 221           221         222           Afghanistan      Asia           611
# 113           113         114               Armenia      Asia          8007
# 122           122         123            Azerbaijan      Asia          6757
# 55             55          56               Bahrain      Asia         28385
# 172           172         173            Bangladesh      Asia          2469
# 160           160         161                Bhutan      Asia          3497
# 44             44          45                Brunei      Asia         35103
# 179           179         180              Cambodia      Asia          1896
# 90             90          91                 China      Asia         13721
# 46             46          47                Cyprus      Asia         33807
# 116           116         117               Georgia      Asia          7600
# ...

# %%
#What is European Union[n 1]?

The European Union (EU) is a unique political and economic partnership of 27 European countries,
creating a single market for free movement of goods, capital, services, and people,
operating with its own institutions (Parliament, Council, Commission) to set laws,
budgets, and policies, promoting peace, trade, and shared values like human rights across its member states.
Article 1

The official languages and the working languages of the institutions of the Community shall be
Dutch, French, German and Italian.
The term "n of 1" implies that there is no other comparable entity for a proper comparative analysis,
making the EU a singular case study for Single Market

# %%
# GDP Analysis based on World Bank Estimate Data

wbankdf=df[["Country/Territory","UN_Region","WorldBank_Estimate","WorldBank_Year"]]
wbankdf.sort_values(by="UN_Region")
# Out:
#     Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 222           Burundi    Africa                 222            2021
# 174           Nigeria    Africa                2066            2021
# 175             Kenya    Africa                2082            2021
# 177             Ghana    Africa                2363            2021
# 73         Seychelles    Africa               14653            2021
# ..                ...       ...                 ...             ...
# 75       Cook Islands   Oceania                   0               0
# 70   French Polynesia   Oceania               19915            2021
# 146        Micronesia   Oceania                3571            2021
# 99              Nauru   Oceania               10648            2021
# 92              World     World               12235            2021
#
# [223 rows x 4 columns]

# %%
WB=wbankdf[wbankdf["WorldBank_Estimate"]!=0]
WB
# Out:
#     Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 0              Monaco    Europe              234316            2021
# 1       Liechtenstein    Europe              157755            2020
# 2          Luxembourg    Europe              133590            2021
# 3             Ireland    Europe              100172            2021
# 4             Bermuda  Americas              114090            2021
# ..                ...       ...                 ...             ...
# 218            Malawi    Africa                 635            2021
# 219       South Sudan    Africa                1072            2015
# 220      Sierra Leone    Africa                 480            2021
# 221       Afghanistan      Asia                 369            2021
# 222           Burundi    Africa                 222            2021
#
# [216 rows x 4 columns]

# %%
from types import BuiltinFunctionType
from matplotlib import pyplot as plt
import seaborn as sns

ax=sns.barplot(x="UN_Region", y="WorldBank_Estimate", data=WB,  errorbar=None, width=0.5)
plt.title("GDP Analysis of Regions based on World Bank Estimate Data of all Years")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns

ax=sns.barplot(x="WorldBank_Year", y="WorldBank_Estimate", data=WB,  errorbar=None, width=0.5 )
plt.title("Average GDP Analysis of World Bank Estimate Data by Year of UN_Regions")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
Average=WB["WorldBank_Estimate"].mean()
print(Average)
# Out:
# 19540.805555555555

# %%
GDP_greater_AVG=WB[WB["WorldBank_Estimate"]>Average]
GDP_greater_AVG
# Out:
#              Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 0                       Monaco    Europe              234316            2021
# 1                Liechtenstein    Europe              157755            2020
# 2                   Luxembourg    Europe              133590            2021
# 3                      Ireland    Europe              100172            2021
# 4                      Bermuda  Americas              114090            2021
# ..                         ...       ...                 ...             ...
# 61                    Slovakia    Europe               21392            2021
# 62                      Greece    Europe               20193            2021
# 64  Saint Martin (French part)  Americas               21921            2014
# 67    Turks and Caicos Islands  Americas               20909            2021
# 70            French Polynesia   Oceania               19915            2021
#
# [64 rows x 4 columns]

# %%
GDP_lesser_AVG=WB[WB["WorldBank_Estimate"]<Average]
GDP_lesser_AVG
# Out:
#     Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 63               Oman      Asia               19510            2021
# 65            Uruguay  Americas               17313            2021
# 66           Barbados  Americas               17226            2021
# 68             Guyana  Americas                9999            2021
# 69            Croatia    Europe               17685            2021
# ..                ...       ...                 ...             ...
# 218            Malawi    Africa                 635            2021
# 219       South Sudan    Africa                1072            2015
# 220      Sierra Leone    Africa                 480            2021
# 221       Afghanistan      Asia                 369            2021
# 222           Burundi    Africa                 222            2021
#
# [152 rows x 4 columns]

# %%
# Countries in Europe below average

# %%
GDP_lesser_AVG=WB[WB["WorldBank_Estimate"]<Average]
GDP_lesser_AVG.groupby("UN_Region").get_group("Europe").sort_values(by="WorldBank_Estimate")
# Out:
#           Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 142                 Ukraine    Europe                4836            2021
# 126                 Moldova    Europe                5231            2021
# 132                  Kosovo    Europe                5270            2021
# 119                 Albania    Europe                6493            2021
# 117         North Macedonia    Europe                6695            2021
# 111  Bosnia and Herzegovina    Europe                7143            2021
# 114                 Belarus    Europe                7302            2021
# 105                  Serbia    Europe                9230            2021
# 102              Montenegro    Europe                9466            2021
# 89                   Russia    Europe               12195            2021
# 86                 Bulgaria    Europe               12222            2021
# 77                  Romania    Europe               14858            2021
# ...

# %%
GDP_greater_AVG=WB[WB["WorldBank_Estimate"]>Average]
GDP_grt_Eur_AVG=GDP_greater_AVG.groupby("UN_Region").get_group("Europe").sort_values(by="WorldBank_Estimate")
GDP_grt_Eur_AVG
# Out:
#       Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 62               Greece    Europe               20193            2021
# 59               Latvia    Europe               21148            2021
# 61             Slovakia    Europe               21392            2021
# 56            Lithuania    Europe               23723            2021
# 58             Portugal    Europe               24568            2021
# 51       Czech Republic    Europe               26821            2021
# 53              Estonia    Europe               27944            2021
# 50             Slovenia    Europe               29291            2021
# 52                Spain    Europe               30104            2021
# 39                Malta    Europe               33487            2021
# 40                Italy    Europe               35658            2021
# 35  European Union[n 1]    Europe               38411            2021
# ...

# %%
## Which countries in Europe has lower GDP than UK? The WorldBank_Estimate of UK=46510

GDP_grt_Eur_AVG[(GDP_grt_Eur_AVG["WorldBank_Estimate"] < 46510)]
# Out:
#       Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 62               Greece    Europe               20193            2021
# 59               Latvia    Europe               21148            2021
# 61             Slovakia    Europe               21392            2021
# 56            Lithuania    Europe               23723            2021
# 58             Portugal    Europe               24568            2021
# 51       Czech Republic    Europe               26821            2021
# 53              Estonia    Europe               27944            2021
# 50             Slovenia    Europe               29291            2021
# 52                Spain    Europe               30104            2021
# 39                Malta    Europe               33487            2021
# 40                Italy    Europe               35658            2021
# 35  European Union[n 1]    Europe               38411            2021
# ...

# %%
## Which countries in Europe has higher GDP than UK?
GDP_grt_Eur_AVG[(GDP_grt_Eur_AVG["WorldBank_Estimate"] > 46510)]
# Out:
#    Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 27           Germany    Europe               51204            2021
# 23           Belgium    Europe               51247            2021
# 19           Austria    Europe               53638            2021
# 22           Finland    Europe               53655            2021
# 17       Netherlands    Europe               57768            2021
# 21            Sweden    Europe               61029            2021
# 15           Denmark    Europe               68008            2021
# 12           Iceland    Europe               68728            2021
# 14     Faroe Islands    Europe               69010            2021
# 13   Channel Islands    Europe               75153            2007
# 8        Isle of Man    Europe               87158            2019
# 5             Norway    Europe               89154            2021
# 6        Switzerland    Europe               91992            2021
# ...

# %% [markdown]
# ## groupby()

# %% [markdown]
# [Learn more about groupby](https://www.geeksforgeeks.org/pandas-groupby/)

# %%
WB.groupby(["UN_Region","WorldBank_Year"]).get_group(("Europe",2019)).sort_values(by="WorldBank_Estimate")
# Out:
#   Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 8       Isle of Man    Europe               87158            2019

# %%
WB.groupby(["UN_Region","WorldBank_Year"]).get_group(("Europe",2020)).sort_values(by="WorldBank_Estimate")
# Out:
#    Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 24        San Marino    Europe               45320            2020
# 1      Liechtenstein    Europe              157755            2020

# %%
WB.groupby(["UN_Region","WorldBank_Year"]).get_group(("Europe", 2021)).sort_values(by="WorldBank_Estimate")
# Out:
#           Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 142                 Ukraine    Europe                4836            2021
# 126                 Moldova    Europe                5231            2021
# 132                  Kosovo    Europe                5270            2021
# 119                 Albania    Europe                6493            2021
# 117         North Macedonia    Europe                6695            2021
# 111  Bosnia and Herzegovina    Europe                7143            2021
# 114                 Belarus    Europe                7302            2021
# 105                  Serbia    Europe                9230            2021
# 102              Montenegro    Europe                9466            2021
# 89                   Russia    Europe               12195            2021
# 86                 Bulgaria    Europe               12222            2021
# 77                  Romania    Europe               14858            2021
# ...

# %%
WB.groupby(["UN_Region","WorldBank_Year"]).get_group(("Asia", 2021)).sort_values(by="WorldBank_Estimate")
# Out:
#         Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 221           Afghanistan      Asia                 369            2021
# 194            Tajikistan      Asia                 897            2021
# 191                 Nepal      Asia                1208            2021
# 197               Myanmar      Asia                1210            2021
# 182            Kyrgyzstan      Asia                1277            2021
# 185              Pakistan      Asia                1505            2021
# 179              Cambodia      Asia                1625            2021
# 170            Uzbekistan      Asia                1983            2021
# 167                 India      Asia                2257            2021
# 172            Bangladesh      Asia                2458            2021
# 180                  Laos      Asia                2536            2021
# 188           Timor-Leste      Asia                2741            2021
# ...

# %% [markdown]
# **WorldBank Estimate for Year 2021**

# %%
#Group by WorldBank year and sort the UN_Region for Year 2021 only.
WB_21=WB.groupby("WorldBank_Year").get_group(2021)
(WB_21)
# Out:
#             Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 0                      Monaco    Europe              234316            2021
# 2                  Luxembourg    Europe              133590            2021
# 3                     Ireland    Europe              100172            2021
# 4                     Bermuda  Americas              114090            2021
# 5                      Norway    Europe               89154            2021
# ..                        ...       ...                 ...             ...
# 217  Central African Republic    Africa                 461            2021
# 218                    Malawi    Africa                 635            2021
# 220              Sierra Leone    Africa                 480            2021
# 221               Afghanistan      Asia                 369            2021
# 222                   Burundi    Africa                 222            2021
#
# [199 rows x 4 columns]

# %%
# AVERAGE WORLD BANK GDP For YEAR 2021
WB_21=WB.groupby("WorldBank_Year").get_group(2021)
WB_21_Avg=WB_21["WorldBank_Estimate"].mean()
print(WB_21_Avg)
# Out:
# 18224.206030150755

# %%
#WORLD BANK GDP For YEAR 2021 - Countries greater than Average GDP
WB_21_Grt_Avg= WB_21[WB_21["WorldBank_Estimate"]>WB_21_Avg]
WB_21_Grt_Avg.sort_values(by="WorldBank_Estimate")
# Out:
#            Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 74                   Hungary    Europe               18728            2021
# 63                      Oman      Asia               19510            2021
# 70          French Polynesia   Oceania               19915            2021
# 62                    Greece    Europe               20193            2021
# 67  Turks and Caicos Islands  Americas               20909            2021
# 59                    Latvia    Europe               21148            2021
# 61                  Slovakia    Europe               21392            2021
# 54              Saudi Arabia      Asia               23186            2021
# 56                 Lithuania    Europe               23723            2021
# 58                  Portugal    Europe               24568            2021
# 55                   Bahrain      Asia               26563            2021
# ...

# %%
WB_21_Grt_Avg= WB_21[WB_21["WorldBank_Estimate"]>WB_21_Avg]
WB_21_Grt_Avg_25=WB_21_Grt_Avg.head(25)
WB_21_Grt_Avg_25.plot(y='Country/Territory', x='WorldBank_Estimate', kind='scatter',
        figsize=(10,6),
        title="25 Countries with GDP Greater than Average Year 2021")

plt.show()

# %%
#WORLD BANK GDP For YEAR 2021 - Countries lesser than Average GDP
WB_21_Less_Avg= WB_21[WB_21["WorldBank_Estimate"]< WB_21_Avg]
WB_21_Less_Avg.sort_values(by=("WorldBank_Estimate"))
# Out:
#             Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 222                   Burundi    Africa                 222            2021
# 221               Afghanistan      Asia                 369            2021
# 215                   Somalia    Africa                 447            2021
# 217  Central African Republic    Africa                 461            2021
# 220              Sierra Leone    Africa                 480            2021
# ..                        ...       ...                 ...             ...
# 65                    Uruguay  Americas               17313            2021
# 69                    Croatia    Europe               17685            2021
# 81                    Curaçao  Americas               17718            2021
# 71                     Poland    Europe               18000            2021
# 79      Saint Kitts and Nevis  Americas               18083            2021
#
# [143 rows x 4 columns]

# %%
#WORLD BANK GDP For YEAR 2021 - 25 Countries lesser than Average GDP Ascending Order
WB_21_Less_Avg_25=WB_21_Less_Avg.tail(25).sort_values(by="WorldBank_Estimate")
WB_21_Less_Avg_25
# Out:
#             Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 222                   Burundi    Africa                 222            2021
# 221               Afghanistan      Asia                 369            2021
# 215                   Somalia    Africa                 447            2021
# 217  Central African Republic    Africa                 461            2021
# 220              Sierra Leone    Africa                 480            2021
# 213                Mozambique    Africa                 492            2021
# 216                Madagascar    Africa                 501            2021
# 209                  DR Congo    Africa                 577            2021
# 212                     Niger    Africa                 591            2021
# 218                    Malawi    Africa                 635            2021
# 207                   Liberia    Africa                 676            2021
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
WB_21_Less_Avg_25.plot(kind='scatter', x ='WorldBank_Estimate', y ='Country/Territory', figsize=(10,6))
plt.title("25 Countries with GDP lesser than Average Year 2021")
plt.show()

# %%
WB_21_country=WB.groupby("WorldBank_Year").get_group(2021).sort_values(by="WorldBank_Estimate")
WB_21_country_25=WB_21_country.head(25)
WB_21_country.head(25)
# Out:
#             Country/Territory UN_Region  WorldBank_Estimate  WorldBank_Year
# 222                   Burundi    Africa                 222            2021
# 221               Afghanistan      Asia                 369            2021
# 215                   Somalia    Africa                 447            2021
# 217  Central African Republic    Africa                 461            2021
# 220              Sierra Leone    Africa                 480            2021
# 213                Mozambique    Africa                 492            2021
# 216                Madagascar    Africa                 501            2021
# 209                  DR Congo    Africa                 577            2021
# 212                     Niger    Africa                 591            2021
# 218                    Malawi    Africa                 635            2021
# 207                   Liberia    Africa                 676            2021
# ...

# %% [markdown]
# **Which country has highest Worldbank Estimate for year 2021**

# %%
WB_21['WorldBank_Estimate'].agg(['max','min'])
# Out:
# max    234316
# min       222
# Name: WorldBank_Estimate, dtype: int64

# %%
WB_21['WorldBank_Estimate'].max()
# Out:
# 234316

# %%
WB_21_Country_max = WB_21.loc[WB_21['WorldBank_Estimate'].idxmax(), 'Country/Territory']
WB_21_Country_max
# Out:
# 'Monaco'

# %%
WB_21['WorldBank_Estimate'].min()
# Out:
# 222

# %%
WB_21_Country_min = WB_21.loc[WB_21['WorldBank_Estimate'].idxmin(), 'Country/Territory']
WB_21_Country_min
# Out:
# 'Burundi'

# %% [markdown]
# ## Which countries below average by IMF world estimate?

# %% [markdown]
# ### IMF estimate 0 values

# %% [markdown]
# ## Which country has highest UN Estimate?

# %% [markdown]
# ## Which country has highest IMF Estimate?

# %% [markdown]
# ## Filling 0 Values by average

# %%
import numpy as np

# %%
# replace 0 with null values

# %%
# Calculate the average of 'Worldbank_Estimate' and 'UN_Estimate' columns

# %%
# Fill the null values in 'imf' column with the calculated average

# %%
# Drop the temporary 'avg_worldbank_un' column if not needed

# %% [markdown]
# [Visit this link to learn more about ffill](https://www.w3schools.com/python/pandas/ref_df_ffill.asp)

# %% [markdown]
# [Visit this link to learn more about bfill](https://www.w3schools.com/python/pandas/ref_df_bfill.asp)

# %% [markdown]
# ## Checking Missing Values

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
WB.hist(figsize=(10,8))
plt.show()

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=5, figsize=(12,9))

plt.show()

# %%
234316/5
#1 bin size if bins=5
# Out:
# 46863.2

# %%
234316/10
#1 bin size if bins not given any number

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].hist(bins=15, figsize=(15,12))

#23400/15 = 15300
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))
sns.heatmap(corr)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True)

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, fmt=".2f", cmap = 'GnBu', annot_kws={"size": 12})

plt.show()

# %%
corr = df[["IMF_Estimate", "UN_Estimate", "WorldBank_Estimate"]].corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.title("Correlation Map")


plt.show()

# %%
corr = df.select_dtypes(include=[int, float]).corr()

plt.figure(figsize=(9,6))

sns.heatmap(corr, annot=True, cmap = 'Purples')

plt.show()

# %% [markdown]
# ### Bar plot

# %%
df.head()

# %%
sns.barplot(x="WorldBank_Estimate", y="UN_Region", data=df, errorbar=None)

plt.show()

# %%
fig = plt.figure(figsize = (8,5))

ax = sns.barplot(x = "IMF_Estimate",  y = "UN_Region",
data = df, errorbar = None)

ax.bar_label(ax.containers[0])

plt.show()

# %%
fig = plt.figure(figsize = (8,5))
ax = sns.barplot(x = "UN_Region",  y = "IMF_Estimate",
                 data = df, errorbar = None)

ax.bar_label(ax.containers[0])


ax.set_title("Regions by IMF Estimate")
plt.show()

# %% [markdown]
# ### Scatter Plot

# %% [markdown]
# ### Boxplot and Outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %%
sns.boxplot(x=df["UN_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>50000].head()

# %%
sns.boxplot(x=df["WorldBank_Estimate"])

plt.show()

# %%
sns.boxplot(x=df["IMF_Estimate"])

plt.show()

# %%
df[df["UN_Estimate"]>100000]

# %%
df.UN_Estimate.mean()

# %%
df.shape

# %% [markdown]
# ## Create another dataframe called data excluding  5 countries with highest UN estimate

# %%
data = df[-(df["UN_Estimate"]>100000)]

# %%
data.head()

# %%
data.shape

# %%
data.UN_Estimate.mean()

# %%
df.UN_Estimate.mean()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x=data["UN_Estimate"])
plt.show()

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# ![image.png](attachment:da6a7715-3b1c-4165-a2a9-4dc8ca096bd7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lower_q = df["UN_Estimate"].quantile(0.25)
lower_q

# %%
higher_q = df["UN_Estimate"].quantile(0.75)
higher_q

# %%
iqr = higher_q - lower_q
iqr

# %%
upper_boundary = higher_q + 1.5 * iqr
upper_boundary

# %%
lower_boundary = lower_q - 1.5 * iqr
lower_boundary

# %%
df_filtered = df[(df["UN_Estimate"] < upper_boundary) & (df["UN_Estimate"] > lower_boundary)]

# %%
df_filtered.head()

# %%
df_filtered.shape
# there were 223 rows - 196 = 27 outliers dropped

# %%
df_filtered.UN_Estimate.mean()

# %%
df.UN_Estimate.mean()

# %%
#how can we create a table with following
df_filtered.WorldBank_Estimate.mean()

# %%
df.WorldBank_Estimate.mean()

# %%
df_filtered.IMF_Estimate.mean()

# %%
df.IMF_Estimate.mean()
# Out:
# np.float64(15351.632286995517)

# %%
# Geosynchronous Orbit Calculator
import math
G = 6.67e-11 # m^3 s^-2

# Input sidereal day length
days = float(input('days'))
hours = float(input('hours'))
minutes = float(input('minutes'))
seconds = float(input('seconds'))

# Convert sidereal day to seconds
TimeInSeconds = 86400*days + 3600*hours + 60*minutes + seconds
print('Sidereal day in seconds =', TimeInSeconds)

# Planet physical characteristics
mass = float(input('input mass')) # kg
radius = float(input('input planet radius')) # m


def KeplersThirdRadius(period,mass):
    radius = math.cbrt((G*mass*period**2)/(4*math.pi**2))
    return radius

print('Semi-Major Axis = ' ,KeplersThirdRadius(TimeInSeconds,mass), 'm')
if KeplersThirdRadius(TimeInSeconds,mass)<radius:
    print('Synchronous orbit does not exist. Radius of the orbit is below the surface!')
else:
    print('surface altitude = ', KeplersThirdRadius(TimeInSeconds,mass)-radius, 'm =', (KeplersThirdRadius(TimeInSeconds,mass)-radius)/1000, 'km')


# Example usage:
# Earth mass = 5.9722e24 kg
# Earth radius = 6371e3 m
# Earth Sidereal day = 23h 56m 4s
# Expected Semi-Major axis = 42155 km
# Out:
# days23
# hours12
# minutes45
# seconds50
# Sidereal day in seconds = 2033150.0
# input mass5.9722e24
# input planet radius6371e3
# Semi-Major Axis =  346800536.5122494 m
# surface altitude =  340429536.5122494 m = 340429.5365122494 km

# %%
# Example usage:
# Earth mass = 5.9722e24 kg
# Earth radius = 6371e3 m
# Earth Sidereal day = 23h 56m 4s
# Expected Semi-Major axis = 42155 km
